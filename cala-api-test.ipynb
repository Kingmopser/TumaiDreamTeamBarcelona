# %%
import requests

url = "https://api.cala.ai/v1/knowledge/query"

query = "startups.location=Spain.funding>10M.funding<50M"
payload = { "input": query }
headers = {
    "X-API-KEY": "clsk_FRQR0883vhHSTkFH6x8RnvbYUZvB9qx4IEN3foGFqlo",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'results': [{'startup': 'Quibim', 'funding': '~€48M ($50M)', 'round': 'Series A', 'sector': 'AI Medical Imaging / HealthTech', 'hq': 'Valencia'}, {'startup': 'PropHero', 'funding': '€16M', 'round': 'Series A', 'sector': 'PropTech', 'hq': 'Madrid'}, {'startup': 'Embat', 'funding': '€14.7M', 'round': 'Series A', 'sector': 'Fintech / Treasury Management', 'hq': 'Madrid'}, {'startup': 'Highlight Therapeutics', 'funding': '€15M', 'round': 'Series Unknown', 'sector': 'Biotech / Cancer Treatment', 'hq': 'Spain'}, {'startup': 'Wooptix', 'funding': '>€10M', 'round': 'Series C', 'sector': 'Semiconductor Metrology', 'hq': 'Madrid / Canary Islands'}, {'startup': 'Sateliot', 'funding': '€30M', 'round': 'Series B', 'sector': 'Satellite IoT / Space', 'hq': 'Barcelona'}], 'entities': []}

# %%
import requests

url = "https://api.cala.ai/v1/knowledge/query"

headers = {
    "X-API-KEY": "clsk_FRQR0883vhHSTkFH6x8RnvbYUZvB9qx4IEN3foGFqlo",
    "Content-Type": "application/json"
}

payload = {
    "input": "companies.industry=AI.location=Germany"
}

res = requests.post(url, json=payload, headers=headers)
print(res.json())
# Out:
# {'results': [{'company': 'DeepL SE', 'location': 'Cologne, Nordrhein-Westfalen', 'description': 'AI-powered machine translation and language technology; ~900 employees. Total funding: ~$415M'}, {'company': 'Aleph Alpha GmbH', 'location': 'Heidelberg, Baden-Württemberg', 'description': 'Developer of large language models and enterprise AI solutions; founded 2019'}, {'company': 'Celonis SE', 'location': 'Munich, Bavaria', 'description': 'AI-driven process mining and execution management platform'}, {'company': 'SAP', 'location': 'Walldorf, Baden-Württemberg', 'description': 'Enterprise software giant with significant AI/cloud capabilities'}, {'company': 'Black Forest Labs', 'location': 'Germany', 'description': 'Generative AI company (image generation models)'}, {'company': 'deepset', 'location': 'Berlin', 'description': 'Developer of AI frameworks for building NLP and LLM applications'}, {'company': 'Jina AI', 'location': 'Berlin', 'description': 'Open-source AI company focused on mul
# ...

# %%
import requests

url = "https://api.cala.ai/v1/knowledge/query"

headers = {
    "X-API-KEY": "clsk_FRQR0883vhHSTkFH6x8RnvbYUZvB9qx4IEN3foGFqlo",
    "Content-Type": "application/json"
}

payload = {
    "input": "companies.exchange=NASDAQ.revenue_growth>0.2.net_income>0"
}

res = requests.post(url, json=payload, headers=headers)
print(res.json())
# Out:
# {'results': [{'company': 'NVIDIA', 'ticker': 'NVDA', 'revenue_growth': '~114% YoY (FY2025 quarterly)', 'net_income': '$31.9 B (Q3 FY2026, ended Oct 2025)', 'exchange': 'NASDAQ'}, {'company': 'Meta Platforms', 'ticker': 'META', 'revenue_growth': '~22% YoY (2024)', 'net_income': '$18.3 B (Q2 2025)', 'exchange': 'NASDAQ'}, {'company': 'Fortinet', 'ticker': 'FTNT', 'revenue_growth': '~23% revenue CAGR (5-year)', 'net_income': None, 'exchange': 'NASDAQ'}, {'company': 'AMSC', 'ticker': 'AMSC', 'revenue_growth': '~53% (FY2024)', 'net_income': '$6 M (FY2024)', 'exchange': 'NASDAQ'}, {'company': 'BillionToOne', 'ticker': 'BLLN', 'revenue_growth': '~117% (Q3 2025 YoY)', 'net_income': '$1.5 M (Q3 2025)', 'exchange': 'NASDAQ'}], 'entities': [{'id': '42f01bdd-3ad8-4263-9e57-f2971dbca16f', 'name': 'NASDAQ Stock Market', 'entity_type': 'Organization', 'mentions': ['NASDAQ']}, {'id': '5f7ca504-01d8-4aa9-b1ac-889202fd17c9', 'name': 'NVIDIA CORP', 'entity_type': 'Company', 'mentions': ['NVIDIA', 'NVDA
# ...

# %%
r = requests.post(                                                          
        "https://different-cormorant-663.convex.site/api/submit",               
        json=payload,                                                           
        headers={"Content-Type": "application/json"}                            
    )                                                                           
print(r.status_code, r.json())
# Out:
# 400 {'error': "Missing or invalid 'team_id'"}
